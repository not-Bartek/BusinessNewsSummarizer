# %% [markdown]
# # Business News Summarizer

# %% [markdown]
# ## Importing dependencies

# %%
from dotenv import load_dotenv
import os
import requests
import feedparser
from bs4 import BeautifulSoup
import torch
from transformers import AutoTokenizer, AutoModel
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
from bs4 import BeautifulSoup

# %% [markdown]
# ## Model parameters

# %%
model_path = 'microsoft/codebert-base'
device = "cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu"

# %%
tokenizer = AutoTokenizer.from_pretrained("microsoft/codebert-base")
model = AutoModel.from_pretrained("microsoft/codebert-base")

# %%
model = model.to(device)

# %% [markdown]
# ## Creating Dataframe

# %%
rss_url = "http://feeds.bbci.co.uk/news/business/rss.xml"
feed = feedparser.parse(rss_url)

# %%
df_news = pd.read_csv('sample_news.csv')

# %% [markdown]
# ## Embedding

# %%
titles = df_news['title'].tolist()[:50]  # 50 najnowszych tytułów
titles = df_news['title'].tolist()[:50]  # 50 najnowszych tytułów

# %%
with torch.no_grad():
    inputs = tokenizer(titles, padding=True, truncation=True, return_tensors="pt")
    inputs = {k: v.to(device) for k, v in inputs.items()}
    outputs = model(**inputs)
    # Najczęściej używa się wektora CLS jako embeddingu
    embeddings = outputs.last_hidden_state[:, 0, :].cpu().numpy()

print("Embedding shape:", embeddings.shape)
# Out:
# Embedding shape: (25, 768)

# %% [markdown]
# ## Embedding prompt

# %%
prompt = "How the stocks of Tesla will change"

# %%
with torch.no_grad():
    prompt_inputs = tokenizer([prompt], padding=True, truncation=True, return_tensors="pt")
    prompt_inputs = {k: v.to(device) for k, v in prompt_inputs.items()}
    prompt_outputs = model(**prompt_inputs)
    prompt_embedding = prompt_outputs.last_hidden_state[:, 0, :].cpu().numpy()

# %%
similarities = cosine_similarity(prompt_embedding, embeddings)[0]
top5_idx = np.argsort(similarities)[-5:][::-1]

# %%
for idx in top5_idx:
    print(f"Title: {df_news['title'].iloc[idx]}")
    print(f"Similarity: {similarities[idx]:.4f}")
    print("---")
# Out:
# Title: Starbucks opens 1000th store in China
# Similarity: 0.9982
# ---
# Title: Intel to build new factory in US
# Similarity: 0.9980
# ---
# Title: Tesla shares surge after record deliveries
# Similarity: 0.9979
# ---
# Title: Disney+ reaches 200M subscribers
# Similarity: 0.9977
# ---
# Title: Microsoft invests in quantum computing startup
# Similarity: 0.9976
# ---

# %% [markdown]
# ## Parsing data from chosed articles

# %%
def get_article_text(url):
    try:
        response = requests.get(url, timeout=10)
        soup = BeautifulSoup(response.text, 'html.parser')
        paragraphs = soup.find_all('p')
        text = ' '.join([p.get_text() for p in paragraphs])
        return text.strip()
    except Exception as e:
        return f"Error: {e}"

# %%
top5_df = df_news.iloc[top5_idx].reset_index(drop=True)
top5_df['content'] = top5_df['link'].apply(get_article_text)
top5_df
# Out:
#                                             title  \
# 0           Starbucks opens 1000th store in China
# 1                Intel to build new factory in US
# 2      Tesla shares surge after record deliveries
# 3                Disney+ reaches 200M subscribers
# 4  Microsoft invests in quantum computing startup
#
#                                    link  \
# 0  https://www.bbc.com/news/business-21
# 1  https://www.bbc.com/news/business-10
# 2   https://www.bbc.com/news/business-1
# 3  https://www.bbc.com/news/business-20
# 4   https://www.bbc.com/news/business-4
#
#                                              summary        date  \
# 0      Starbucks celebrates rapid expansion in Asia.  2025-12-29
# 1  Intel plans a $10B investment in a new US faci...  2026-01-03
# 2  Tesla delivered a record number of vehicles in...  2026-01-08
# 3  Disney+ hits a major milestone in streaming wars.  2025-12-29
# 4  Microsoft's investment aims to accelerate quan...  2026-01-06
#
#                                              content
# 0  Sorry, we're unable to bring you the page you'...
# 1  Sorry, we're unable to bring you the page you'...
# 2  Sorry, we're unable to bring you the page you'...
# 3  Sorry, we're unable to bring you the page you'...
# 4  Sorry, we're unable to bring you the page you'...

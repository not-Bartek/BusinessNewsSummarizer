# %% [markdown]
# # Business News Summarizer

# %% [markdown]
# ## Importing dependencies

# %%
from dotenv import load_dotenv
import os
import requests
import feedparser
from bs4 import BeautifulSoup
import torch
from transformers import AutoTokenizer, AutoModel
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
from bs4 import BeautifulSoup

# %% [markdown]
# ## Model parameters

# %%
model_path = 'microsoft/codebert-base'
device = "cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu"

# %%
tokenizer = AutoTokenizer.from_pretrained("microsoft/codebert-base")
model = AutoModel.from_pretrained("microsoft/codebert-base")

# %%
model = model.to(device)

# %% [markdown]
# ## Creating Dataframe

# %%
rss_url = "http://feeds.bbci.co.uk/news/business/rss.xml"
feed = feedparser.parse(rss_url)

articles = []

for entry in feed.entries:
    articles.append({
        'title': entry.title,
        'link': entry.link,
        'summary': entry.summary if 'summary' in entry else '',
        'published': entry.published if 'published' in entry else ''
    })

df_news = pd.DataFrame(articles)
df_news
# Out:
#                                                 title  \
# 0   Government to water down business rate rise fo...
# 1        Weight loss jabs affecting Greggs, boss says
# 2   Tesco and M&S report strong  Christmas food sales
# 3   Inside the sub-zero lair of the world's most p...
# 4   Unions accuse McDonald's of 'repeated harassme...
# 5   How tariff disruption will continue reshaping ...
# 6   Workers' rights reforms will cost billions les...
# 7   Trump calls for US military spending to rise m...
# 8   Sportswear firm Castore defends price of footb...
# 9   Trump backs ban on institutional investor home...
# 10  Elon Musk's Grok AI appears to have made child...
# 11  US will control Venezuela oil sales 'indefinit...
# 12  Young people say new driving rules are condesc...
# 13  Starmer urged to rethink business rate reforms...
# 14  Learner drivers may have to wait six months be...
# 15  Warner Bros urges shareholders to reject 'infe...
# 16  The 'magical' blue flower changing farmers' fo...
# 17  What are cold weather payments and who can get...
# 18  Trump says Venezuela will be 'turning over' up...
# 19  Fujitsu 'not a parasite' for profiting after H...
# 20  Nestle issues global recall of some baby formu...
# 21  Next raises profit forecast to £1.15bn after b...
# 22  Electric car discounts are unsustainable, says...
# 23  Claire's and The Original Factory Shop to ente...
# 24  Car giant Hyundai to use human-like robots in ...
# 25  Anonymous crypto gambler made $436,000 on Madu...
# 26  Nvidia unveils self-driving car tech as it see...
# 27  How the new road safety measures could affect you
# 28  How the defence sector is battling a skills cr...
# 29  Swedish workers trial 'friendship hour' to com...
# 30  The showers and baths keeping data centre tech...
# 31  Why Croatia's capital wants to hold Europe's b...
# 32  Will tech trump tradition at bakers and biscui...
# 33  Should more be done to tackle 'ghost jobs', va...
# 34  Why this month's inflation figure may be good ...
# 35           Meet the biggest heat pumps in the world
# 36       Homeless charity concerned over energy costs
# 37  Upfront childcare payments 'simplifies the sys...
# 38  Trump backs ban on institutional investor home...
# 39  Target 'divisive' Reform in 2026, Keir Starmer...
# 40        Warm Welcome helps fight cold and isolation
# 41  Budget 2025: What's the best and worst that co...
# 42  Has Britain's budget watchdog become too all-p...
# 43  The curious case of why Poundland is strugglin...
# 44  The £5.30 orange juice that tells the story of...
# 45  How Milei's 'Thatcherite' economics divided hi...
# 46                                        The Inquiry
# 47  What does TikTok's deal mean for America's users?
# 48                                          Americast
# 49  Who are the winners and losers of the interest...
#
#                                                  link  \
# 0   https://www.bbc.com/news/articles/c8e57dexly1o...
# 1   https://www.bbc.com/news/articles/c20g11y4dywo...
# 2   https://www.bbc.com/news/articles/cp82ylmy6d1o...
# 3   https://www.bbc.com/news/articles/c62r6dvpl5ro...
# 4   https://www.bbc.com/news/articles/c2e1g17drr2o...
# 5   https://www.bbc.com/news/articles/czejp3gep63o...
# 6   https://www.bbc.com/news/articles/c5yv6n536vno...
# 7   https://www.bbc.com/news/articles/cy59kxl2xwzo...
# 8   https://www.bbc.com/news/articles/c1lzv94qnpyo...
# 9   https://www.bbc.com/news/articles/c0lxz5wn2yzo...
# 10  https://www.bbc.com/news/articles/cvg1mzlryxeo...
# 11  https://www.bbc.com/news/articles/ckgn7p7g79wo...
# 12  https://www.bbc.com/news/articles/c4gr3rlpgnqo...
# 13  https://www.bbc.com/news/articles/cy59k2rdkv5o...
# 14  https://www.bbc.com/news/articles/clym5jvgdepo...
# 15  https://www.bbc.com/news/articles/c79rd5l7w7jo...
# 16  https://www.bbc.com/news/articles/clyxln49760o...
# 17  https://www.bbc.com/news/articles/c87470q4w21o...
# 18  https://www.bbc.com/news/articles/c4grxzxjjd8o...
# 19  https://www.bbc.com/news/articles/cdxjnv1qzgxo...
# 20  https://www.bbc.com/news/articles/cx2yvx8gnnpo...
# 21  https://www.bbc.com/news/articles/cre27x179zpo...
# 22  https://www.bbc.com/news/articles/c0417v3v21ko...
# 23  https://www.bbc.com/news/articles/c78v6v0j8v4o...
# 24  https://www.bbc.com/news/articles/cvgjm5x54ldo...
# 25  https://www.bbc.com/news/articles/cx2gn93292do...
# 26  https://www.bbc.com/news/articles/c0jv1vd571wo...
# 27  https://www.bbc.com/news/articles/ckgxy9p117no...
# 28  https://www.bbc.com/news/articles/clyd1lpp1lyo...
# 29  https://www.bbc.com/news/articles/c4g5ry7749po...
# 30  https://www.bbc.com/news/articles/cp8zd176516o...
# 31  https://www.bbc.com/news/articles/c8dy5m56477o...
# 32  https://www.bbc.com/news/articles/cly5gen0gj8o...
# 33  https://www.bbc.com/news/articles/clyzvpp8g3vo...
# 34  https://www.bbc.com/news/articles/c0r9x1xx0x7o...
# 35  https://www.bbc.com/news/articles/c17p44w87rno...
# 36  https://www.bbc.com/news/articles/c39410el00po...
# 37  https://www.bbc.com/news/articles/c23rnrz831ro...
# 38  https://www.bbc.com/news/articles/c0lxz5wn2yzo...
# 39  https://www.bbc.com/news/articles/c150z39e705o...
# 40  https://www.bbc.com/news/articles/c3dmxnyeg91o...
# 41  https://www.bbc.com/news/articles/cqlk5gd3kv9o...
# 42  https://www.bbc.com/news/articles/clyx9n5p7v7o...
# 43  https://www.bbc.com/news/articles/c4gkgxeeyzno...
# 44  https://www.bbc.com/news/articles/c397n3jl3z8o...
# 45  https://www.bbc.com/news/articles/c9865l8540eo...
# 46  https://www.bbc.co.uk/sounds/play/w3ct723q?at_...
# 47  https://www.bbc.com/news/videos/c5yje8pvg8jo?a...
# 48  https://www.bbc.co.uk/sounds/play/p0mpmfcp?at_...
# 49  https://www.bbc.com/news/videos/c0l9ele319lo?a...
#
#                                               summary  \
# 0   The hospitality industry had called for a reth...
# 1   The Greggs boss says there is "no doubt" weigh...
# 2   Both major retailers report strong food sales,...
# 3   Faisal Islam gets rare access to Willow - Goog...
# 4   It follows a BBC investigation three years ago...
# 5   Trump's import levies are still changing the p...
# 6   Firms implementing the new employment terms ar...
# 7   The president also called on defence firms to ...
# 8   Tom Beahon, of sportswear firm Castore, says f...
# 9   Wall Street investors have bought thousands of...
# 10  It said analysts discovered the images on a da...
# 11  Officials say sales were expected to start wit...
# 12  Young drivers have spoken to the BBC about how...
# 13  Some Labour MPs are optimistic there could be ...
# 14  Proposed changes by the government may also in...
# 15  The Warner Bros board said it remained unanimo...
# 16  Indian farmers are turning to butterfly pea fl...
# 17  Some people in England, Wales and Northern Ire...
# 18  Earlier the president said US oil firms could ...
# 19  The European boss of the tech firm said it had...
# 20  The food giant discovered some batches of SMA ...
# 21  Festive trading at the retailer beat expectati...
# 22  The SMMT warned of a growing gap between consu...
# 23  The firms' owner said "alarming" low Christmas...
# 24  The firm plans to deploy the technology at the...
# 25  The account placed a $32,000 wager just before...
# 26  The chip giant is looking for ways to move the...
# 27  The government is proposing lowering alcohol l...
# 28  Attracting younger workers into the defence in...
# 29  The pilot project is even giving staff free mo...
# 30  Finding greener ways to keep giant new data ce...
# 31  The festive events help to put cities on the m...
# 32  Introducing robots and automation to the food ...
# 33  Companies are advertising vacancies that have ...
# 34  The rate of inflation, which charts the rising...
# 35  Across Europe huge heat pumps are being instal...
# 36  An increasing number of people cannot afford t...
# 37  Paying parents directly for some childcare cos...
# 38  Wall Street investors have bought thousands of...
# 39  The PM says Labour needs to contrast its "rene...
# 40  This Warm Welcome venue is one of more than 80...
# 41  Three days in, after a tax U-turn and partial ...
# 42  Ahead of this week's Budget, some have accused...
# 43  Why - in an age where so many of us are feelin...
# 44  Butter, chocolate, coffee and milk have all se...
# 45  Ahead of Milei's visit to the White House - am...
# 46  How did live music evolve into a billion-dolla...
# 47  The BBC's Asia business correspondent says it ...
# 48  The president makes a primetime address to the...
# 49  The Bank of England has cut interest rates fro...
#
#                         published
# 0   Thu, 08 Jan 2026 16:21:46 GMT
# 1   Thu, 08 Jan 2026 15:38:19 GMT
# 2   Thu, 08 Jan 2026 13:42:32 GMT
# 3   Thu, 08 Jan 2026 08:03:50 GMT
# 4   Thu, 08 Jan 2026 00:00:14 GMT
# 5   Thu, 08 Jan 2026 00:00:40 GMT
# 6   Thu, 08 Jan 2026 11:07:03 GMT
# 7   Thu, 08 Jan 2026 02:15:51 GMT
# 8   Thu, 08 Jan 2026 09:38:59 GMT
# 9   Wed, 07 Jan 2026 22:38:36 GMT
# 10  Thu, 08 Jan 2026 09:58:38 GMT
# 11  Wed, 07 Jan 2026 20:31:48 GMT
# 12  Wed, 07 Jan 2026 16:12:54 GMT
# 13  Thu, 08 Jan 2026 10:01:01 GMT
# 14  Wed, 07 Jan 2026 10:35:04 GMT
# 15  Wed, 07 Jan 2026 13:20:10 GMT
# 16  Tue, 06 Jan 2026 00:01:52 GMT
# 17  Wed, 07 Jan 2026 13:12:06 GMT
# 18  Wed, 07 Jan 2026 10:10:24 GMT
# 19  Tue, 06 Jan 2026 17:56:44 GMT
# 20  Tue, 06 Jan 2026 08:43:47 GMT
# 21  Tue, 06 Jan 2026 11:15:07 GMT
# 22  Tue, 06 Jan 2026 09:48:31 GMT
# 23  Mon, 05 Jan 2026 19:59:02 GMT
# 24  Tue, 06 Jan 2026 03:26:38 GMT
# 25  Mon, 05 Jan 2026 23:44:35 GMT
# 26  Tue, 06 Jan 2026 10:30:23 GMT
# 27  Wed, 07 Jan 2026 15:37:07 GMT
# 28  Fri, 02 Jan 2026 00:53:13 GMT
# 29  Tue, 30 Dec 2025 04:04:25 GMT
# 30  Tue, 23 Dec 2025 00:04:45 GMT
# 31  Mon, 22 Dec 2025 01:05:38 GMT
# 32  Fri, 19 Dec 2025 00:07:27 GMT
# 33  Thu, 18 Dec 2025 00:00:37 GMT
# 34  Wed, 17 Dec 2025 14:18:10 GMT
# 35  Tue, 16 Dec 2025 00:06:44 GMT
# 36  Thu, 08 Jan 2026 15:24:36 GMT
# 37  Thu, 08 Jan 2026 06:25:15 GMT
# 38  Wed, 07 Jan 2026 22:38:36 GMT
# 39  Tue, 06 Jan 2026 16:40:05 GMT
# 40  Tue, 06 Jan 2026 09:27:02 GMT
# 41  Sat, 29 Nov 2025 15:14:47 GMT
# 42  Tue, 25 Nov 2025 00:00:03 GMT
# 43  Fri, 21 Nov 2025 08:03:37 GMT
# 44  Wed, 22 Oct 2025 06:58:17 GMT
# 45  Tue, 14 Oct 2025 12:26:40 GMT
# 46  Thu, 01 Jan 2026 08:30:00 GMT
# 47  Fri, 19 Dec 2025 09:22:13 GMT
# 48  Fri, 19 Dec 2025 11:42:00 GMT
# 49  Thu, 18 Dec 2025 14:06:55 GMT

# %% [markdown]
# ## Embedding

# %%
titles = df_news['title'].tolist()[:50]  # 50 najnowszych tytułów
titles = df_news['title'].tolist()[:50]  # 50 najnowszych tytułów

# %%
with torch.no_grad():
    inputs = tokenizer(titles, padding=True, truncation=True, return_tensors="pt")
    inputs = {k: v.to(device) for k, v in inputs.items()}
    outputs = model(**inputs)
    # Najczęściej używa się wektora CLS jako embeddingu
    embeddings = outputs.last_hidden_state[:, 0, :].cpu().numpy()

print("Embedding shape:", embeddings.shape)
# Out:
# Embedding shape: (50, 768)

# %% [markdown]
# ## Embedding prompt

# %%
prompt = "How the stocks of Tesla will change"

# %%
with torch.no_grad():
    prompt_inputs = tokenizer([prompt], padding=True, truncation=True, return_tensors="pt")
    prompt_inputs = {k: v.to(device) for k, v in prompt_inputs.items()}
    prompt_outputs = model(**prompt_inputs)
    prompt_embedding = prompt_outputs.last_hidden_state[:, 0, :].cpu().numpy()

# %%
similarities = cosine_similarity(prompt_embedding, embeddings)[0]
top5_idx = np.argsort(similarities)[-5:][::-1]

# %%
for idx in top5_idx:
    print(f"Title: {df_news['title'].iloc[idx]}")
    print(f"Similarity: {similarities[idx]:.4f}")
    print("---")
# Out:
# Title: The showers and baths keeping data centre tech cool
# Similarity: 0.9980
# ---
# Title: How the new road safety measures could affect you
# Similarity: 0.9980
# ---
# Title: Meet the biggest heat pumps in the world
# Similarity: 0.9979
# ---
# Title: Nestle issues global recall of some baby formula products over toxin fears
# Similarity: 0.9978
# ---
# Title: The 'magical' blue flower changing farmers' fortunes in India
# Similarity: 0.9978
# ---

# %% [markdown]
# ## Parsing data from chosed articles

# %%
def get_article_text(url):
    try:
        response = requests.get(url, timeout=10)
        soup = BeautifulSoup(response.text, 'html.parser')
        paragraphs = soup.find_all('p')
        text = ' '.join([p.get_text() for p in paragraphs])
        #TODO - implement removing useless words, adds etc
        return text.strip()
    except Exception as e:
        return f"Error: {e}"

# %%
top5_df = df_news.iloc[top5_idx].reset_index(drop=True)
top5_df['content'] = top5_df['link'].apply(get_article_text)
top5_df
# Out:
#                                                title  \
# 0  The showers and baths keeping data centre tech...
# 1  How the new road safety measures could affect you
# 2           Meet the biggest heat pumps in the world
# 3  Nestle issues global recall of some baby formu...
# 4  The 'magical' blue flower changing farmers' fo...
#
#                                                 link  \
# 0  https://www.bbc.com/news/articles/cp8zd176516o...
# 1  https://www.bbc.com/news/articles/ckgxy9p117no...
# 2  https://www.bbc.com/news/articles/c17p44w87rno...
# 3  https://www.bbc.com/news/articles/cx2yvx8gnnpo...
# 4  https://www.bbc.com/news/articles/clyxln49760o...
#
#                                              summary  \
# 0  Finding greener ways to keep giant new data ce...
# 1  The government is proposing lowering alcohol l...
# 2  Across Europe huge heat pumps are being instal...
# 3  The food giant discovered some batches of SMA ...
# 4  Indian farmers are turning to butterfly pea fl...
#
#                        published  \
# 0  Tue, 23 Dec 2025 00:04:45 GMT
# 1  Wed, 07 Jan 2026 15:37:07 GMT
# 2  Tue, 16 Dec 2025 00:06:44 GMT
# 3  Tue, 06 Jan 2026 08:43:47 GMT
# 4  Tue, 06 Jan 2026 00:01:52 GMT
#
#                                              content
# 0  They work 24/7 at high speeds and get searingl...
# 1  The UK government has launched the first major...
# 2  The pipe that will supply the heat pump, drawi...
# 3  Nestle has issued a global recall of some baby...
# 4  "Until a few years ago, the butterfly pea flow...

# %% [markdown]
# ## Creating agents
